# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishitha0730/Computer-Vision/blob/main/Image%20Operation/Images_With_OpenCV_and_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import images & read

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('/butterfly.png')
plt.imshow(image)

# %%
image.shape
# Out:
# (800, 800, 3)

# %% [markdown]
# # Resize the image

# %%
resized_image = cv2.resize(image,(200,200))
plt.imshow(resized_image)

# %%
resized_image.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# # Crop the image

# %%
cropped_image = image[100:680,40:750]
plt.imshow(cropped_image)

# %% [markdown]
# # Convert BGR to HSV

# %%
hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
plt.imshow(hsv_image)

# %% [markdown]
# # Convert back to BGR

# %%
rgb_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2BGR)
plt.imshow(rgb_image)
